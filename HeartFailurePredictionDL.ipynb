# %%
# set up
import pandas as pd
import numpy as np
from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.layers import InputLayer

# suppress the warnings
import warnings
warnings.filterwarnings("ignore")

# %%
# load the dataset
data = pd.read_csv("heart_failure_clinical_records_dataset.csv")
data.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# 2        1     7            1
# 3        0     7            1
# 4        0     8            1

# %%
# inspect the dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
# inspect the distribution of the outcome
print("The distribution of heart failure records in the dataset:")
print(Counter(data['DEATH_EVENT']))
# Out:
# The distribution of heart failure records in the dataset:
# Counter({0: 203, 1: 96})

# %%
# split teh dataset into features and labels
labels = data['DEATH_EVENT']
features = data.drop('DEATH_EVENT', axis=1)

# split the dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)

# scale the numeric features using ColumnTransformer
numeric_cols = ['age','creatinine_phosphokinase','ejection_fraction','platelets','serum_creatinine','serum_sodium','time']
ct = ColumnTransformer(transformers=[
    ("scaler", StandardScaler(), numeric_cols)
])
X_train = ct.fit_transform(X_train)
X_test = ct.transform(X_test)

# convert the labels into categorical
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
# design the model
model = Sequential()
model.add(InputLayer(shape=(X_train.shape[1],)))
model.add(Dense(12, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(2, activation="softmax"))

# compile the model
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

# fit the model
history = model.fit(X_train, y_train, epochs=100, batch_size=16, verbose=2)
# Out:
# Epoch 1/100
# 15/15 - 1s - 36ms/step - accuracy: 0.6192 - loss: 0.7981
# Epoch 2/100
# 15/15 - 0s - 2ms/step - accuracy: 0.6736 - loss: 0.7730
# Epoch 3/100
# 15/15 - 0s - 2ms/step - accuracy: 0.6736 - loss: 0.7116
# Epoch 4/100
# 15/15 - 0s - 2ms/step - accuracy: 0.7238 - loss: 0.6677
# Epoch 5/100
# 15/15 - 0s - 2ms/step - accuracy: 0.7071 - loss: 0.6732
# Epoch 6/100
# 15/15 - 0s - 2ms/step - accuracy: 0.7406 - loss: 0.6324
# Epoch 7/100
# 15/15 - 0s - 2ms/step - accuracy: 0.6946 - loss: 0.6046
# Epoch 8/100
# 15/15 - 0s - 2ms/step - accuracy: 0.7322 - loss: 0.6019
# Epoch 9/100
# 15/15 - 0s - 2ms/step - accuracy: 0.7280 - loss: 0.6154
# Epoch 10/100
# 15/15 - 0s - 2ms/step - accuracy: 0.7531 - loss: 0.5765
# Epoch 11/100
# 15/15 - 0s - 2ms/step - accuracy: 0.7448 - loss: 0.5624
# Epoch 12/100
# 15/15 - 0s - 2ms/step - accuracy: 0.7531 - loss: 0.5336
# Epoch 13/100
# 15/15 - 0s - 2ms/step - accuracy: 0.7866 - loss: 0.4946
# Epoch 14/100
# 15/15 - 0s - 2ms/step - accuracy: 0.7824 - loss: 0.5136
# Epoch 15/100
# 15/15 - 0s - 2ms/step - accuracy: 0.7531 - loss: 0.5083
# Epoch 16/100
# 15/15 - 0s - 2ms/step - accuracy: 0.7741 - loss: 0.4875
# Epoch 17/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8159 - loss: 0.4652
# Epoch 18/100
# 15/15 - 0s - 2ms/step - accuracy: 0.7866 - loss: 0.4582
# Epoch 19/100
# 15/15 - 0s - 2ms/step - accuracy: 0.7782 - loss: 0.4618
# Epoch 20/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8117 - loss: 0.4340
# Epoch 21/100
# 15/15 - 0s - 2ms/step - accuracy: 0.7950 - loss: 0.4597
# Epoch 22/100
# 15/15 - 0s - 2ms/step - accuracy: 0.7866 - loss: 0.4361
# Epoch 23/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8159 - loss: 0.4313
# Epoch 24/100
# 15/15 - 0s - 2ms/step - accuracy: 0.7950 - loss: 0.4523
# Epoch 25/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8159 - loss: 0.4331
# Epoch 26/100
# 15/15 - 0s - 2ms/step - accuracy: 0.7908 - loss: 0.4416
# Epoch 27/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8285 - loss: 0.4121
# Epoch 28/100
# 15/15 - 0s - 2ms/step - accuracy: 0.7992 - loss: 0.4294
# Epoch 29/100
# 15/15 - 0s - 2ms/step - accuracy: 0.7992 - loss: 0.4287
# Epoch 30/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8201 - loss: 0.3980
# Epoch 31/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8033 - loss: 0.3990
# Epoch 32/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8243 - loss: 0.3851
# Epoch 33/100
# 15/15 - 0s - 2ms/step - accuracy: 0.7992 - loss: 0.3922
# Epoch 34/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8201 - loss: 0.3996
# Epoch 35/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8201 - loss: 0.3825
# Epoch 36/100
# 15/15 - 0s - 2ms/step - accuracy: 0.7908 - loss: 0.3836
# Epoch 37/100
# 15/15 - 0s - 2ms/step - accuracy: 0.7950 - loss: 0.4079
# Epoch 38/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8326 - loss: 0.3936
# Epoch 39/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8159 - loss: 0.3689
# Epoch 40/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8285 - loss: 0.3806
# Epoch 41/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8285 - loss: 0.3694
# Epoch 42/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8243 - loss: 0.3767
# Epoch 43/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8326 - loss: 0.3638
# Epoch 44/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8368 - loss: 0.3717
# Epoch 45/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8075 - loss: 0.4033
# Epoch 46/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8075 - loss: 0.3720
# Epoch 47/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8368 - loss: 0.3490
# Epoch 48/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8452 - loss: 0.3580
# Epoch 49/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8159 - loss: 0.3802
# Epoch 50/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8285 - loss: 0.3633
# Epoch 51/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8536 - loss: 0.3451
# Epoch 52/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8033 - loss: 0.3714
# Epoch 53/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8326 - loss: 0.3376
# Epoch 54/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8452 - loss: 0.3404
# Epoch 55/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8577 - loss: 0.3373
# Epoch 56/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8326 - loss: 0.3646
# Epoch 57/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8368 - loss: 0.3518
# Epoch 58/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8577 - loss: 0.3150
# Epoch 59/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8285 - loss: 0.3683
# Epoch 60/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8577 - loss: 0.3372
# Epoch 61/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8326 - loss: 0.3475
# Epoch 62/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8577 - loss: 0.3158
# Epoch 63/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8494 - loss: 0.3440
# Epoch 64/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8536 - loss: 0.3492
# Epoch 65/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8536 - loss: 0.3262
# Epoch 66/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8368 - loss: 0.3474
# Epoch 67/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8201 - loss: 0.3362
# Epoch 68/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8243 - loss: 0.3570
# Epoch 69/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8577 - loss: 0.3149
# Epoch 70/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8285 - loss: 0.3386
# Epoch 71/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8452 - loss: 0.3455
# Epoch 72/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8536 - loss: 0.3102
# Epoch 73/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8285 - loss: 0.3293
# Epoch 74/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8661 - loss: 0.3119
# Epoch 75/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8243 - loss: 0.3531
# Epoch 76/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8452 - loss: 0.3524
# Epoch 77/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8494 - loss: 0.3548
# Epoch 78/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8619 - loss: 0.3201
# Epoch 79/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8536 - loss: 0.3174
# Epoch 80/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8285 - loss: 0.3412
# Epoch 81/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8494 - loss: 0.3204
# Epoch 82/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8536 - loss: 0.3164
# Epoch 83/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8494 - loss: 0.3304
# Epoch 84/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8536 - loss: 0.2985
# Epoch 85/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8326 - loss: 0.3510
# Epoch 86/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8494 - loss: 0.3219
# Epoch 87/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8368 - loss: 0.3365
# Epoch 88/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8494 - loss: 0.2959
# Epoch 89/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8285 - loss: 0.3359
# Epoch 90/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8619 - loss: 0.3254
# Epoch 91/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8452 - loss: 0.3416
# Epoch 92/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8368 - loss: 0.3060
# Epoch 93/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8410 - loss: 0.3244
# Epoch 94/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8452 - loss: 0.3341
# Epoch 95/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8536 - loss: 0.3062
# Epoch 96/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8494 - loss: 0.3109
# Epoch 97/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8410 - loss: 0.3235
# Epoch 98/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8619 - loss: 0.3090
# Epoch 99/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8452 - loss: 0.3201
# Epoch 100/100
# 15/15 - 0s - 2ms/step - accuracy: 0.8577 - loss: 0.3043

# %%
# evaluate the model
loss, acc = model.evaluate(X_test, y_test)
print("Loss: ", loss)
print("Accuracy: ", acc)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7715 - loss: 0.5582
# Loss:  0.5662959218025208
# Accuracy:  0.7666666507720947

# %%
y_estimate = model.predict(X_test)
y_estimate = np.argmax(y_estimate, axis=1)
y_true = np.argmax(y_test, axis=1)
print(classification_report(y_true, y_estimate))
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
#               precision    recall  f1-score   support
#
#            0       0.72      0.97      0.83        35
#            1       0.92      0.48      0.63        25
#
#     accuracy                           0.77        60
#    macro avg       0.82      0.73      0.73        60
# weighted avg       0.81      0.77      0.75        60
